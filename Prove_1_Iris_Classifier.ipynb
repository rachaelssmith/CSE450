# %% [markdown]
# <a href="https://colab.research.google.com/github/rachaelssmith/CSE450/blob/master/Prove_1_Iris_Classifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#classification of Fisher's Iris dataset

#import the following files
import random
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

#load the data
url = "https://byui-cs.github.io/cs450-course/week01/iris.data"
df = pd.read_csv(url)
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
#randomize data
df = df.sample(frac=1)
df
# Out:
#     sepal_length  sepal_width  petal_length  petal_width          species
# 43           5.0          3.5           1.6          0.6      Iris-setosa
# 92           5.8          2.6           4.0          1.2  Iris-versicolor
# 81           5.5          2.4           3.7          1.0  Iris-versicolor
# 68           6.2          2.2           4.5          1.5  Iris-versicolor
# 17           5.1          3.5           1.4          0.3      Iris-setosa
# ..           ...          ...           ...          ...              ...
# 66           5.6          3.0           4.5          1.5  Iris-versicolor
# 77           6.7          3.0           5.0          1.7  Iris-versicolor
# 73           6.1          2.8           4.7          1.2  Iris-versicolor
# 64           5.6          2.9           3.6          1.3  Iris-versicolor
# 80           5.5          2.4           3.8          1.1  Iris-versicolor
#
# [150 rows x 5 columns]

# %%
#split the data into features and targets
targets = df[['species']]
features = df[['sepal_length', 'sepal_width', 'petal_length', 'petal_width']]

#randomize and split the samples into two groups.
#30% of the samples will be used for testing.
#the other 70% will be used for training.
train_data, test_data, train_targets, test_targets = train_test_split(features, targets, test_size =.3)

print ("train data shape: "+str(train_data.shape+train_targets.shape))
print ("test data shape: "+str(test_data.shape+test_targets.shape))
# Out:
# train data shape: (105, 4, 105, 1)
# test data shape: (45, 4, 45, 1)

# %%
class HardCodedClassifier:
    def __init__(self, data, targets):
        self.data = data
        self.targets = targets
        
    def fit(self, data, targets):
        train_data = data
        train_targets = targets
        classifier = GaussianNB()
        classifier.fit(train_data, train_targets)
        
    def predict(self, data):
      targets_predicted = classifier.predict(test_data)
      return targets_predicted

# %%
def main():
    #Prediction Test
    hcc = HardCodedClassifier(train_data,train_targets)
    predictions = hcc.predict(test_targets)
    p_dataframe = pd.DataFrame(predictions)
    p_dataframe.rename(index=str, columns={1:'species'})
    accuracy = accuracy_score(test_targets, predictions)

    new_targets_list = test_targets
    new_targets_list = new_targets_list.reset_index()

    final = pd.concat([p_dataframe, new_targets_list], axis=1,join='outer',ignore_index=True)
    final.columns = ['Prediction Species:', 'Index:', 'Training Species:']
    print(final)
    print("")
    print("Accuracy: \n\t"+format(accuracy,'.2f'))
    
if __name__ == "__main__":
    main()
# Out:
#    Prediction Species:  Index: Training Species:
# 0          Iris-setosa      19       Iris-setosa
# 1          Iris-setosa      49       Iris-setosa
# 2      Iris-versicolor      92   Iris-versicolor
# 3          Iris-setosa      16       Iris-setosa
# 4       Iris-virginica     121    Iris-virginica
# 5      Iris-versicolor      87   Iris-versicolor
# 6          Iris-setosa      15       Iris-setosa
# 7      Iris-versicolor      79   Iris-versicolor
# 8          Iris-setosa      39       Iris-setosa
# 9      Iris-versicolor      94   Iris-versicolor
# 10      Iris-virginica     105    Iris-virginica
# 11     Iris-versicolor      88   Iris-versicolor
# 12     Iris-versicolor      51   Iris-versicolor
# 13      Iris-virginica     100    Iris-virginica
# 14     Iris-versicolor      57   Iris-versicolor
# 15     Iris-versicolor      67   Iris-versicolor
# 16         Iris-setosa      42       Iris-setosa
# 17     Iris-versicolor      85   Iris-versicolor
# ...
